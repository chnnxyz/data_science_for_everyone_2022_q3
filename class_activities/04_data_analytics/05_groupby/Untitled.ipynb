# %%
import seaborn as sns

# %%
import pandas as pd

# %%
mtcars = sns.load_dataset('mpg')

# %%
mtcars.head()
# Out:
#     mpg  cylinders  displacement  horsepower  weight  acceleration  \
# 0  18.0          8         307.0       130.0    3504          12.0
# 1  15.0          8         350.0       165.0    3693          11.5
# 2  18.0          8         318.0       150.0    3436          11.0
# 3  16.0          8         304.0       150.0    3433          12.0
# 4  17.0          8         302.0       140.0    3449          10.5
#
#    model_year origin                       name
# 0          70    usa  chevrolet chevelle malibu
# 1          70    usa          buick skylark 320
# 2          70    usa         plymouth satellite
# 3          70    usa              amc rebel sst
# 4          70    usa                ford torino

# %%
gb = mtcars.groupby(['cylinders','origin','model_year'])

# %%
gb.max().sort_values('acceleration')
# Out:
#                               mpg  displacement  horsepower  weight  \
# cylinders origin model_year
# 6         japan  80          32.7         168.0       132.0    2910
# 3         japan  80          23.7          70.0       100.0    2420
#                  72          19.0          70.0        97.0    2330
#                  73          18.0          70.0        90.0    2124
#                  77          21.5          80.0       110.0    2720
# ...                           ...           ...         ...     ...
# 4         usa    76          29.0         140.0        92.0    2572
#           europe 72          26.0         121.0       112.0    2979
#                  80          44.3         146.0        88.0    3250
#                  82          44.0         105.0        74.0    2130
#                  79          37.3         141.0        71.0    3190
#
#                              acceleration                  name
# cylinders origin model_year
# ...
